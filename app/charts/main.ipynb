# %%
from click import style
import streamlit as st
import pandas as pd
import duckdb
import os

motherduck_token = os.environ.get("motherduck_token")
con = duckdb.connect(f'md:ticktick_gtd?motherduck_token={motherduck_token}')
cur = con.cursor()

def highlight_cell(val):
    if val < 20:
        color = 'yellow' 
    # elif val < 80:
    #     color = 'yellow'
    # elif val < 75:
    #     color = 'orange'
    elif val == 100:
        color = 'blue'
    else: 
        color = ''
    return f'background-color: {color}'

def highlight_text(val):
    if val == 100:
        return 'color: #86acff; font-weight: bold;'
    elif 0 <= val < 100:
        # Calculate the RGB values for a color between red and green based on the progress
        r = int(255 * (1 - val/100))
        g = int(255 * (val/100))
        b = 0
        return f'color: rgb({r}, {g}, {b}); font-weight: bold;'
    else:
        return ''

def highlight_row(row):
    if any(row.astype(str).str.count('-') >= 4):
         return ['background-color: gray; font-weight: bold;'] * len(row)
    else:
        return [''] * len(row)

st.set_page_config(page_title="MY GTD DASHBOARD", layout="wide", initial_sidebar_state="collapsed", menu_items=None)
# [theme]
# base="light"
# primaryColor="#86acff"



# df=lvl1_lvl2_progress
# df=df.style.map(highlight_low_val,subset=['done_progress','clarify_progress'])
obt=cur.sql("select * from obt").df() 


# with st.sidebar:
#     folders = obt['fld_folder_name'].drop_duplicates().to_list()
#     filter_folder = st.multiselect('folders',folders,default=folders)


# st.write("# lvl1-lvl2 analytics")
# st.write("## progress summary")
lvl1_lvl2_progress = cur.query("select * from lvl1_lvl2_progress").df()

filtered_lvl1_lvl2_progress = lvl1_lvl2_progress[lvl1_lvl2_progress['fld_folder_name'].isin(filter_folder)]
colored_lvl1_lvl2_progress = filtered_lvl1_lvl2_progress.style.map(
    highlight_text,subset=['done_progress','clarify_progress']
).apply(
    highlight_row
)
final_lvl1_lvl2_progress = colored_lvl1_lvl2_progress

# st.dataframe(
#     final_lvl1_lvl2_progress,
#     column_config={
#         "done_progress": st.column_config.ProgressColumn(
#         "done_progress",
#         format="%f",
#         min_value=0,
#         max_value=100
#     ),
#     "clarify_progress": st.column_config.ProgressColumn(
#         "clarify_progress",
#         format="%f",
#         min_value=0,
#         max_value=100
#     )
#     },

#     hide_index=True,
#     use_container_width=True
#     )

# %%
final_lvl1_lvl2_progress
# Out:
# <style type="text/css">
# #T_5f771_row0_col1, #T_5f771_row1_col1, #T_5f771_row2_col1, #T_5f771_row3_col1, #T_5f771_row4_col1, #T_5f771_row5_col1, #T_5f771_row6_col1, #T_5f771_row7_col1, #T_5f771_row8_col1, #T_5f771_row9_col1, #T_5f771_row10_col1, #T_5f771_row11_col1, #T_5f771_row12_col1, #T_5f771_row13_col1, #T_5f771_row14_col1, #T_5f771_row15_col1, #T_5f771_row16_col1, #T_5f771_row17_col1, #T_5f771_row18_col1, #T_5f771_row19_col1, #T_5f771_row20_col1, #T_5f771_row21_col1, #T_5f771_row22_col1, #T_5f771_row23_col1, #T_5f771_row24_col1, #T_5f771_row25_col1, #T_5f771_row26_col1, #T_5f771_row27_col1, #T_5f771_row28_col1, #T_5f771_row29_col1, #T_5f771_row30_col1, #T_5f771_row31_col1, #T_5f771_row32_col1, #T_5f771_row33_col1, #T_5f771_row34_col1, #T_5f771_row35_col1, #T_5f771_row36_col1, #T_5f771_row37_col1, #T_5f771_row38_col1, #T_5f771_row39_col1, #T_5f771_row40_col1, #T_5f771_row41_col1, #T_5f771_row42_col1, #T_5f771_row43_col1, #T_5f771_row44_col1, #T_5f771_row45_col1, #T_5f771_row46_col1, #T_5f771_row47_col1, #T_5f771_row48_col1, #T_5f771_row49_col1, #T_5f771_row50_col1, #T_5f771_row51_col1, #T_5f771_row52_col1, #T_5f771_row53_col1, #T_5f771_row54_col1, #T_5f771_row55_col1, #T_5f771_row56_col1, #T_5f771_row57_col1, #T_5f771_row58_col1, #T_5f771_row59_col1, #T_5f771_row60_col1, #T_5f771_row61_col1, #T_5f771_row62_col1, #T_5f771_row63_col1, #T_5f771_row64_col1, #T_5f771_row65_col1 {
#   background-color: gray;
#   font-weight: bold;
# }
# #T_5f771_row0_col2 {
#   color: rgb(100, 154, 0);
#   font-weight: bold;
# }
# #T_5f771_row0_col3 {
#   color: rgb(21, 233, 0);
#   font-weight: bold;
# }
# #T_5f771_row1_col2, #T_5f771_row19_col3, #T_5f771_row20_col2 {
#   color: rgb(170, 84, 0);
#   font-weight: bold;
# }
# #T_5f771_row1_col3, #T_5f771_row2_col3, #T_5f771_row4_col2, #T_5f771_row4_col3, #T_5f771_row5_col3, #T_5f771_row6_col3, #T_5f771_row7_col3, #T_5f771_row8_col3, #T_5f771_row9_col3, #T_5f771_row10_col3, #T_5f771_row11_col3, #T_5f771_row12_col3, #T_5f771_row13_col3, #T_5f771_row14_col3, #T_5f771_row15_col3, #T_5f771_row16_col3, #T_5f771_row17_col3, #T_5f771_row18_col3, #T_5f771_row20_col3, #T_5f771_row22_col3, #T_5f771_row23_col3, #T_5f771_row24_col3, #T_5f771_row26_col3, #T_5f771_row27_col3, #T_5f771_row29_col3, #T_5f771_row30_col3, #T_5f771_row31_col3, #T_5f771_row32_col3, #T_5f771_row33_col3, #T_5f771_row34_col3, #T_5f771_row35_col3, #T_5f771_row36_col3, #T_5f771_row37_col3, #T_5f771_row38_col3, #T_5f771_row39_col3, #T_5f771_row40_col3, #T_5f771_row41_col3, #T_5f771_row42_col3, #T_5f771_row43_col3, #T_5f771_row44_col3, #T_5f771_row45_col3, #T_5f771_row46_col3, #T_5f771_row47_col3, #T_5f771_row48_col3, #T_5f771_row49_col3, #T_5f771_row50_col3, #T_5f771_row51_col3, #T_5f771_row52_col3, #T_5f771_row53_col3, #T_5f771_row54_col3, #T_5f771_row55_col2, #T_5f771_row55_col3, #T_5f771_row56_col3, #T_5f771_row57_col3, #T_5f771_row58_col3, #T_5f771_row59_col3, #T_5f771_row60_col3, #T_5f771_row61_col3, #T_5f771_row62_col3, #T_5f771_row63_col3, #T_5f771_row64_col3, #T_5f771_row65_col3 {
#   color: #86acff;
#   font-weight: bold;
# }
# #T_5f771_row2_col2, #T_5f771_row3_col3, #T_5f771_row14_col2, #T_5f771_row28_col3, #T_5f771_row33_col2, #T_5f771_row38_col2, #T_5f771_row49_col2, #T_5f771_row53_col2, #T_5f771_row57_col2, #T_5f771_row59_col2, #T_5f771_row61_col2, #T_5f771_row62_col2, #T_5f771_row63_col2 {
#   color: rgb(255, 0, 0);
#   font-weight: bold;
# }
# #T_5f771_row3_col2 {
#   color: rgb(153, 102, 0);
#   font-weight: bold;
# }
# #T_5f771_row5_col2, #T_5f771_row26_col2, #T_5f771_row42_col2, #T_5f771_row43_col2 {
#   color: rgb(63, 191, 0);
#   font-weight: bold;
# }
# #T_5f771_row6_col2 {
#   color: rgb(50, 204, 0);
#   font-weight: bold;
# }
# #T_5f771_row7_col2, #T_5f771_row17_col2, #T_5f771_row31_col2, #T_5f771_row39_col2, #T_5f771_row56_col2 {
#   color: rgb(127, 127, 0);
#   font-weight: bold;
# }
# #T_5f771_row8_col2, #T_5f771_row32_col2 {
#   color: rgb(191, 63, 0);
#   font-weight: bold;
# }
# #T_5f771_row9_col2 {
#   color: rgb(11, 243, 0);
#   font-weight: bold;
# }
# #T_5f771_row10_col2 {
#   color: rgb(23, 231, 0);
#   font-weight: bold;
# }
# #T_5f771_row11_col2 {
#   color: rgb(8, 246, 0);
#   font-weight: bold;
# }
# #T_5f771_row12_col2 {
#   color: rgb(198, 56, 0);
#   font-weight: bold;
# }
# #T_5f771_row13_col2 {
#   color: rgb(84, 170, 0);
#   font-weight: bold;
# }
# #T_5f771_row15_col2, #T_5f771_row24_col2 {
#   color: rgb(42, 212, 0);
#   font-weight: bold;
# }
# #T_5f771_row16_col2 {
#   color: rgb(3, 251, 0);
#   font-weight: bold;
# }
# #T_5f771_row18_col2 {
#   color: rgb(111, 143, 0);
#   font-weight: bold;
# }
# #T_5f771_row19_col2 {
#   color: rgb(40, 214, 0);
#   font-weight: bold;
# }
# #T_5f771_row21_col2 {
#   color: rgb(67, 187, 0);
#   font-weight: bold;
# }
# #T_5f771_row21_col3 {
#   color: rgb(102, 153, 0);
#   font-weight: bold;
# }
# #T_5f771_row22_col2 {
#   color: rgb(89, 165, 0);
#   font-weight: bold;
# }
# #T_5f771_row23_col2 {
#   color: rgb(134, 120, 0);
#   font-weight: bold;
# }
# #T_5f771_row25_col2 {
#   color: rgb(156, 98, 0);
#   font-weight: bold;
# }
# #T_5f771_row25_col3 {
#   color: rgb(15, 239, 0);
#   font-weight: bold;
# }
# #T_5f771_row27_col2 {
#   color: rgb(209, 45, 0);
#   font-weight: bold;
# }
# #T_5f771_row28_col2 {
#   color: rgb(229, 25, 0);
#   font-weight: bold;
# }
# #T_5f771_row29_col2 {
#   color: rgb(175, 79, 0);
#   font-weight: bold;
# }
# #T_5f771_row30_col2 {
#   color: rgb(26, 228, 0);
#   font-weight: bold;
# }
# #T_5f771_row34_col2 {
#   color: rgb(204, 51, 0);
#   font-weight: bold;
# }
# #T_5f771_row35_col2 {
#   color: rgb(140, 114, 0);
#   font-weight: bold;
# }
# #T_5f771_row36_col2 {
#   color: rgb(31, 223, 0);
#   font-weight: bold;
# }
# #T_5f771_row37_col2 {
#   color: rgb(151, 103, 0);
#   font-weight: bold;
# }
# #T_5f771_row40_col2 {
#   color: rgb(131, 123, 0);
#   font-weight: bold;
# }
# #T_5f771_row41_col2 {
#   color: rgb(186, 68, 0);
#   font-weight: bold;
# }
# #T_5f771_row44_col2, #T_5f771_row45_col2 {
#   color: rgb(88, 166, 0);
#   font-weight: bold;
# }
# #T_5f771_row46_col2 {
#   color: rgb(177, 77, 0);
#   font-weight: bold;
# }
# #T_5f771_row47_col2 {
#   color: rgb(123, 131, 0);
#   font-weight: bold;
# }
# #T_5f771_row48_col2 {
#   color: rgb(36, 218, 0);
#   font-weight: bold;
# }
# #T_5f771_row50_col2 {
#   color: rgb(159, 95, 0);
#   font-weight: bold;
# }
# #T_5f771_row51_col2 {
#   color: rgb(223, 31, 0);
#   font-weight: bold;
# }
# #T_5f771_row52_col2 {
#   color: rgb(174, 80, 0);
#   font-weight: bold;
# }
# #T_5f771_row54_col2 {
#   color: rgb(145, 109, 0);
#   font-weight: bold;
# }
# #T_5f771_row58_col2 {
#   color: rgb(212, 42, 0);
#   font-weight: bold;
# }
# #T_5f771_row60_col2 {
#   color: rgb(28, 226, 0);
#   font-weight: bold;
# }
# #T_5f771_row64_col2, #T_5f771_row65_col2 {
#   color: rgb(90, 164, 0);
#   font-weight: bold;
# }
# </style>
# <table id="T_5f771">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f771_level0_col0" class="col_heading level0 col0" >fld_folder_name</th>
#       <th id="T_5f771_level0_col1" class="col_heading level0 col1" >l_list_name</th>
#       <th id="T_5f771_level0_col2" class="col_heading level0 col2" >done_progress</th>
#       <th id="T_5f771_level0_col3" class="col_heading level0 col3" >clarify_progress</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f771_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f771_row0_col0" class="data row0 col0" >▶️lvl2 - Innovature</td>
#       <td id="T_5f771_row0_col1" class="data row0 col1" >-----------------------</td>
#       <td id="T_5f771_row0_col2" class="data row0 col2" >60.410000</td>
#       <td id="T_5f771_row0_col3" class="data row0 col3" >91.390000</td>
#     </tr>
#     <tr>
#       <th id="T_5f771_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f771_row1_col0" class="data row1 col0" >▶️lvl2 - Innovature</td>
#       <td id="T_5f771_row1_col1" class="data row1 col1" >1H 2024 comm pi SOP dev handbook</td>
#       <td id="T_5f771_row1_col2" class="data row1 col2" >33.330000</td>
#       <td id="T_5f771_row1_col3" class="data row1 col3" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5f771_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5f771_row2_col0" class="data row2 col0" >▶️lvl2 - Innovature</td>
#       <td id="T_5f771_row2_col1" cl

# %%
folders
