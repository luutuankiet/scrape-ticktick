# %%
from ticktick.oauth2 import OAuth2        # OAuth2 Manager
from ticktick.api import TickTickClient   # Main Interface
from os import environ
from dotenv import load_dotenv

# setup 
load_dotenv('../.secrets')
client_id=environ.get('client_id')
client_secret=environ.get('client_secret')
username=environ.get('username')
password=environ.get('password')
redirect_uri=environ.get('redirect_uri')

auth_client = OAuth2(client_id=client_id,
                     client_secret=client_secret,
                     redirect_uri=redirect_uri)

client = TickTickClient(username, password, auth_client)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 16
#      11 password=environ.get('password')
#      12 redirect_uri=environ.get('redirect_uri')
#      14 auth_client = OAuth2(client_id=client_id,
#      15                      client_secret=client_secret,
# ---> 16                      redirect_uri=uri)
#      18 client = TickTickClient(username, password, auth_client)
#
# NameError: name 'uri' is not defined

# %%
import os
help(os.environ)

# %%
from dotenv import load_dotenv
help(load_dotenv)
